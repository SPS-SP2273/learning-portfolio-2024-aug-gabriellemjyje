# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good)</span></div>

# %%
import matplotlib

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %% [markdown]
# # Some nomenclature

# %% [markdown]
# # Comparing the two 'dialects'

# %% [markdown]
# # What is OO ax, really?

# %% [markdown]
# # A complete OO example

# %%
x = np.linspace(-np.pi, np.pi, num=100)
cos_x = np.cos(x)
sin_x = np.sin(x)

fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(5, 5),
                       sharex=True)
ax[0].plot(x, cos_x, label=r'$\cos(x)$')
ax[0].fill_between(x, 0, cos_x, alpha=.25)
ax[1].plot(x, sin_x, label=r'$\sin(x)$')
ax[1].fill_between(x, 0, sin_x, alpha=.25)

for a in ax:
    a.legend()
    a.grid(alpha=.25)
    a.set_ylabel('$y$', rotation=0)

ax[1].set_xlabel('$x$')

fig.suptitle(r'$\sin(x)$ and $\cos(x)$')
fig.tight_layout()

# %% [markdown]
# # Multiple rows and columns

# %%
x = np.linspace(-np.pi, np.pi, num=100)
cos_x = np.cos(x)
sin_x = np.sin(x)

fig, ax = plt.subplots(nrows=2, ncols=3,
                       figsize=(10, 3),
                       sharex=True, 
                       sharey=True)
for a in ax.flatten():
    a.plot(x, sin_x)

plt.tight_layout()

# %%
x = np.linspace(-np.pi, np.pi, num=100)
cos_x = np.cos(x)
sin_x = np.sin(x)

fig, ax = plt.subplots(nrows=2, ncols=3,
                       figsize=(10, 3),
                       sharex=True, 
                       sharey=True)
for count, a in enumerate(ax.flatten()):
    if count == 3:
        a.plot(x, 10*cos_x, 'r')
        continue
    a.plot(x, sin_x)
    a.grid(alpha=.25)
    a.spines['right'].set_visible(False) # Despining
    a.spines['top'].set_visible(False)

ax[-1, -1].set_xlim(-10,10)

plt.tight_layout()

# %% [markdown]
# ### Using ax

# %% [markdown]
# ## Sharing axes

# %% [markdown]
# ## Accessing all axes

# %% [markdown]
# # 1 Some nomenclature

# %% [markdown]
# # Other useful plots

# %% [markdown]
# ## Histograms

# %% [markdown]
# ### Data

# %% [markdown]
# ### A quick helper function

# %%
# Your code here

# %% [markdown]
# ### The histogram

# %%
# Your code here

# %% [markdown]
# ## Scatter plots

# %%
data = np.random.rand(10,10) # 10 rows, 10 columns
data = data.reshape(100,1) # 100 rows, 1 column

np.savetxt('hahah.csv', data, delimiter=',')

in_data = np.loadtxt('hahah.csv')
plt.scatter(range(len(in_data)), in_data, alpha=.25)

# %%
data = np.random.rand(100,100) # 100 rows, 100 columns
data = data.reshape(10000,1) # 10000 rows, 1 column

np.savetxt('hahah.csv', data, delimiter=',')

in_data = np.loadtxt('hahah.csv')
plt.scatter(range(len(in_data)), in_data, alpha=.25)

# %% [markdown]
# ## Bar charts

# %% [markdown]
# ## Pie charts
